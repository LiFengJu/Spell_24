# %%
import pandas as pd
import seaborn as sns
df = pd.read_excel('data2.xlsx')

# %%
sns.countplot(x=df['17、'], hue=df['年龄'], data=df, palette='colorblind')
# Out:
# <Axes: xlabel='17、', ylabel='count'>
# C:\Users\16872\OneDrive\Document\Spell\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\16872\OneDrive\Document\Spell\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\16872\OneDrive\Document\Spell\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 40836 (\N{CJK UNIFIED IDEOGRAPH-9F84}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\16872\OneDrive\Document\Spell\venv\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
