# %%
import pandas as pd
import matplotlib.pyplot as plt

all_buses_info = pd.read_csv('output_data/all_buses_info.csv')
all_stations_info = pd.read_csv('output_data/all_stations_info.csv')

station_1_info = pd.read_csv('output_data/station_1_info.csv')

# %%
all_buses_info.plot(kind='bar', x = 'Bus Number',y = 'Total Passengers',figsize=(25, 15), grid=False)
# Out:
# <Axes: xlabel='Bus Number'>

# %%
all_buses_info.plot(kind='bar',x = 'Bus Number' , y='Total Utilization Rate',figsize=(25, 15), grid=False)
# Out:
# <Axes: xlabel='Bus Number'>

# %%
all_stations_info.plot(kind='bar', x='Station ID',y = 'Total Boarding Passengers',figsize=(25, 15), grid=False)
# Out:
# <Axes: xlabel='Station ID'>

# %%
all_stations_info.plot(kind='bar', x='Station ID',y = 'Total Alighting Passengers',figsize=(25, 15), grid=False)
# Out:
# <Axes: xlabel='Station ID'>

# %%
all_stations_info.plot(kind='bar', x='Station ID',y = 'Average Utilization Rate',figsize=(25, 15), grid=False)
# Out:
# <Axes: xlabel='Station ID'>

# %%
station_1_info.plot(kind='bar', y = 'boarding_count',figsize=(25, 15), grid=False)
# Out:
# <Axes: >
