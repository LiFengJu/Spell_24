# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
result_1601 = pd.read_csv('data/result_1601.csv')
result_1601
# Out:
#        factor  influence_x1  probability  predict_label  label  performance
# 0    0.844314      0.751141     0.699373              1    1.0     0.093173
# 1    1.307268      2.099980     0.787056              1    1.0    -0.792712
# 2    3.312883      5.373148     0.964868              1    1.0    -2.060265
# 3    3.080139      5.839165     0.956066              1    1.0    -2.759027
# 4   -0.949874      1.185179     0.278910              0    0.0    -2.135054
# ..        ...           ...          ...            ...    ...          ...
# 154  1.726526      8.832187     0.848967              1    1.0    -7.105661
# 155  3.454330      8.839580     0.969360              1    1.0    -5.385249
# 156  2.657247      8.839185     0.934456              1    0.0    -6.181938
# 157  3.256269      8.837482     0.962898              1    1.0    -5.581213
# 158  2.825669      8.832794     0.944047              1    1.0    -6.007125
#
# [159 rows x 6 columns]

# %%
cm = confusion_matrix(result_1601.label, result_1601.predict_label)
cm
# Out:
# array([[25, 43],
#        [ 0, 91]], dtype=int64)

# %%
fpr, tpr, thresholds = roc_curve(result_1601.label, result_1601.probability)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
result_1601.factor.plot(title='factor')
plt.axhline(y=0, color='r', linestyle='--', label='y=0')

# %%
result_1601.performance.plot(title='performance')
plt.axhline(y=0, color='r', linestyle='--', label='y=0')

# %%
result_1601.influence_x1.plot(title='influence_x1')
plt.axhline(y=0, color='r', linestyle='--', label='y=0')
