# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
data = pd.read_excel('汽车性能指标分值统计表.xlsx')
data = data.set_index('性能评价指标')
angles = np.linspace(0, 2 * np.pi, len(data),endpoint=False).tolist()
angles.append(0)

# %%
plt.figure(figsize=(8, 8))
for col in data.columns:
    values = data[col].tolist() + [data[col].iloc[0]]  # 使雷达图封闭
    plt.polar(angles, values, label=col, linewidth=2, linestyle='solid', marker='o', markersize=8)
# 显示图例
    plt.fill(angles, values, alpha=0.25)
plt.legend()
plt.show()
